# %% [markdown]
# # Visual Studio Python Cell Sound Extension

# %%
print("hello success sound")
# Out:
# hello success sound

# %%
print("hello error sound")
print()ff
# Out:
#   Cell In[2], line 2
#     print()ff
#            ^
# SyntaxError: invalid syntax
